# %%
print('Welcome to the epic survival game!')
print('My name is XZ350 advanced robotic system.')
name = input("What's your name? ")
age = int(input("What's your age?"))

health=100

print("Hello", name, "You are starting with",health,"health")



if age >= 18:
  print("You are indeed old enough to play. You'll just have to sign a waiver...Just kidding.")
    

    
    
    
  ask2play = input("Would you like to begin( yes/no)?").lower()
  if ask2play == "yes":
    print("Loading you into virtual dimension.")
        
  first_choice=input("Your arrival in the lush jungle landscape has startled the animals & natives. You see 2 paths before you. One leads into a canoe on the riverbank leading down the mountain. The other is towards a shining gold object in the distance in the heart of the jungle. Which do you choose (shiny gold/river)?").lower()
  if first_choice=="shiny gold":
          ans1=input("You descend into the unknown jungle before you admiring all the exotic animals. As you climb under a tree a large snake pops out with 3 heads and large fangs. Each of its head shoots a stream of venom at you!! What do you do (roll/jump/stand still)?").lower()
          if ans1=="roll":
            print("You dodged 2 of the 3 venom bursts causing you to lose only 25 health but a bad burn.")
          if ans1=="stand still":
             print("You were struck by venom bursts from all 3 snakes causing you to lose all health.")
          if ans1=="jump":
             print("Smart move! You dodged all incoming venom strikes.")
          if health==0:
             print("Your health is 0. Game over.")
          if health>0:
             print("You live to see another day...You win!")
        
        
  if first_choice=="river":
         print("You take a canoe that takes you down the mountain to a village with overhead smoke and a blazing heat.")
         ans2=input("You get off your canoe and see vicious villagers with spears and knives. You can try to run past them into the jungle, try to fight them with your hands, or jump into a convenient dark hole leading to unknown. (fight/ run/ jump in a hole").lower()
         if ans2=="run":
            print("You try to run but are captured by the mob and taken to their base.")
         if ans2=="fight":
            print("You are quickly defeated.")
         if ans2=="jump in a hole":
            print("The hole leads to a waterfall that lands you into a majestic lake area. You win!")
         if ans2 !="jump in a hole":
            print("Game over!")
        
        
        
        
        
         
        
        
  
  else:
    print("cya")
           
     





















        
  

   
        
     
      
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        

    
        
        
        
        
else:
    print("You are not yet of age to cross the virtual dimension.")
# Out:
# Welcome to the epic survival game!
# My name is XZ350 advanced robotic system.
# What's your name? q
# What's your age?20
# Hello q You are starting with 100 health
# You are indeed old enough to play. You'll just have to sign a waiver...Just kidding.
# Would you like to begin( yes/no)?yes
# Loading you into virtual dimension.
# Your arrival in the lush jungle landscape has startled the animals & natives. You see 2 paths before you. One leads into a canoe on the riverbank leading down the mountain. The other is towards a shining gold object in the distance in the heart of the jungle. Which do you choose (shiny gold/river)?river
# You take a canoe that takes you down the mountain to a village with overhead smoke and a blazing heat.
# You get off your canoe and see vicious villagers with spears and knives. You can try to run past them into the jungle, try to fight them with your hands, or jump into a convenient dark hole leading to unknown. (fight/ run/ jump in a holefight
# ...

# %%
# Out:
#   File "<ipython-input-58-31d67612b1c2>", line 16
#     if ask2play == "yes":
#     ^
# IndentationError: unexpected indent

# %%
# Out:
#   File "<ipython-input-210-6c4f60680adf>", line 26
#     if ans1=="roll":
#     ^
# IndentationError: unexpected indent

# %%
print('Welcome to the epic survival game!')
print('My name is XZ350 advanced robotic system.')
name = input("What's your name? ")
age = int(input("What's your age?"))

health=100

print("Hello", name, "You are starting with",health,"health")



if age >= 18:
  print("You are indeed old enough to play. You'll just have to sign a waiver...Just kidding.")
    

    
    
    
  ask2play = input("Would you like to begin( yes/no)?").lower()
  if ask2play == "yes":
        print("Loading you into virtual dimension.")
        
        first_choice=input("Your arrival in the lush jungle landscape has startled the animals & natives. You see 3 paths before you. One leads into a canoe on the riverbank leading up over the mountain. The other is towards a shining gold object in the distance in the heart of the jungle. Which do you choose (shiny gold/river)?").lower()
        if first_choice=="shiny gold":
         ans1=input("You descend into the unknown jungle before you admiring all the exotic animals. As you climb under a tree a large snake pops out with 3 heads and large fangs. Each of its head shoots a stream of venom at you!! What do you do (roll/jump/stand still)?").lower()
        if ans1=="roll":
         print("You dodged 2 of the 3 venom bursts causing you to lose only 25 health but a bad burn.")
        if ans1=="stand still":
            print("You were struck by venom bursts from all 3 snakes causing you to lose all health.")
            health -=100
        if ans1=="jump":
            print("Smart move! You dodged all incoming venom strikes.")
        if health==0:
           print("Game over.")
        
        
        
        
        if first_choice=="river":
         print("canoe")
        
         
        
        
  
  else:
    print("cya")
           
     





















        
  

   
        
     
      
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        
        

    
        
        
        
        
else:
    print("You are not yet of age to cross the virtual dimension.")
# Out:
# Welcome to the epic survival game!
# My name is XZ350 advanced robotic system.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-d413986cef9b> in <module>
#       1 print('Welcome to the epic survival game!')
#       2 print('My name is XZ350 advanced robotic system.')
# ----> 3 name = input("What's your name? ")
#       4 age = int(input("What's your age?"))
#       5
#
# ~\anaconda5\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\anaconda5\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# ...
